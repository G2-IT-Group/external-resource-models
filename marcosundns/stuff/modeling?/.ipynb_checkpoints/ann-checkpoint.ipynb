# %%
import pandas as pd
ipdata=pd.read_parquet('/stuff/data collection and cleanup/octetdata')

# %%
def toint(cell):
    cell = int(cell)
    return cell
ipdata=ipdata.applymap(toint)

# %%
goodguys=ipdata.loc[lambda ipdata:ipdata['benign'] > 0,:].reset_index(drop=True)
badguys=ipdata.loc[lambda ipdata:ipdata['benign']==0,:].reset_index(drop=True)

badguys=badguys.truncate(after=10000)
balancedip=goodguys.append(badguys)
balancedip=balancedip.reset_index(drop=True)

# %%
from sklearn.preprocessing import OneHotEncoder
encoder=OneHotEncoder()
hotdata=encoder.fit_transform(ipdata.loc[:,'ttl':'4th Octet'])

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(hotdata, ipdata['benign'])

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report

clf=MLPClassifier(alpha=1e-5,max_iter= 400, warm_start = False, shuffle=True)

model=clf.fit(xtrain,ytrain)

ypred=model.predict(xtest)
print(classification_report(ytest,ypred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.95      0.94      0.95      6816
#           1       0.86      0.88      0.87      2643
#
# avg / total       0.93      0.92      0.92      9459

# %%
g2ip=pd.DataFrame({'ttl':[3600],'1st Octet':[172], '2nd Octet':[104],'3rd Octet':[18],'4th Octet':[217]})
g2ip=g2ip[['ttl','1st Octet','2nd Octet','3rd Octet','4th Octet']]

wmip=pd.DataFrame({'ttl':[40048], '1st Octet':[128],'2nd Octet':[239],'3rd Octet':[29],'4th Octet':[10]})
encoder.transform(g2ip.loc[:,'ttl':'4th Octet'])

# %%
firsttwogood=goodguys.loc[:,'1st Octet':'2nd Octet'].reset_index(drop=True)
firsttwobad=badguys.loc[:,'1st Octet': '2nd Octet'].reset_index(drop=True)
plotdatagood=firsttwogood.groupby(firsttwogood.columns.tolist()).size().reset_index()
plotdatabad=firsttwobad.groupby(firsttwobad.columns.tolist()).size().reset_index()

# %%
import altair as alt
alt.renderers.enable('notebook')
plotdatagood=plotdatagood.rename(columns={0:'Counts'})
    
alt.Chart(plotdatagood).mark_rect().encode(x='first:O', y='second:O', color='count').properties(width=256, height=256)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/altair/vegalite/v3/api.py in to_dict(self, *args, **kwargs)
#     367
#     368         try:
# --> 369             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     370         except jsonschema.ValidationError:
#     371             dct = None
#
# ~/anaconda3/lib/python3.6/site-packages/altair/utils/schemapi.py in to_dict(self, validate, ignore, context)
#     283             result = _todict({k: v for k, v in self._kwds.items()
#     284                               if k not in ignore},
# --> 285                               validate=sub_validate, context=context)
#     286         else:
#     287             raise ValueError("{} instance has both a value and properties : "
#
# ...

# %%
plotdatagood
# Out:
#       1st Octet  2nd Octet  Counts
# 0             1        201       4
# 1             2         16      27
# 2             2         17      24
# 3             2         18      42
# 4             2         19      29
# 5             2         20      45
# 6             2         21      19
# 7             2         22      29
# 8             2         23      14
# 9             3          0       2
# 10            3          1       4
# 11            3         17       1
# 12            3         18       1
# 13            3         80       1
# 14            3         81       2
# 15            3         82       2
# 16            3         85       1
# 17            3         88       1
# 18            3         90       2
# 19            3         91       2
# 20            3         92       4
# 21            3         93       7
# 22            3         94       6
# 23            3         95       2
# 24            3        120       1
# 25            3        122       3
# ...
