# %% [markdown]
# # Certificate Characteristics

# %%
import numpy as np
import pandas as pd
import os
from pprint import pprint
import json
import time
import random
import re
from collections import defaultdict
import pickle
import datetime

# %%
everyFile=[]
tmp=os.listdir('/data/data/')
tmp.remove('newbenigndata')
for x in tmp:
    try:
        folder='/data/data/'+x+'/enrichment/cert_info/'
        for y in os.listdir(folder):
            if (len(y) > 10):
                everyFile.append(folder+y)
    except:
        continue

for x in os.listdir('/data/data/newNONTORbenigndata/enrichment/cert_info/'):
        everyFile.append('/data/data/newNONTORbenigndata/enrichment/cert_info/'+x)

# %%
print(len(everyFile))
# Out:
# 18478

# %%
df_cols=['benign', 'indicator', 'error_type', 'cert_validation', 'success', 
         'authorityInfoAccess', 'basicConstraints', 'certificatePolicies',
         'has_expired', 'notAfter', 'notBefore']

col_check=set(df_cols)
error_types=defaultdict(int)
validation_types=defaultdict(int)
usage_types=defaultdict(int)
issuers=defaultdict(int)
ctr=0

lamow=[]
for x in everyFile:
    if (ctr == 50):
        break
        
    try:
        book=json.load(open(x))['data']
        ctr+=1
        for cert_dict in book:
            df=pd.DataFrame(columns=df_cols)
            df['benign']=[len(x)-x.rfind('/')<11]
            infoString=None  
            if (cert_dict.get('cert_info') == None):
                infoString='certificate_info'
            else:
                infoString='cert_info'
                    
            if (type(cert_dict[infoString]) != dict):
                    df['indicator']=[cert_dict['indicator']]
                    df['success']=[cert_dict['success']]
                    try:
                        df['error_type']=re.findall("\[.*\]",cert_dict[infoString])[0]
                    except Exception as s:
                        df['error_type']=[cert_dict[infoString]]
                    
                    error_types[df['error_type'][0]]+=1

            else:
                df['indicator']=[cert_dict['indicator']]
                df['success']=[cert_dict['success']]
                df['cert_validation'] = [cert_dict.get('cert_validation')]
                validation_types[cert_dict.get('cert_validation')]+=1
                    
                if (cert_dict[infoString].get('subject') != None):
                    alpha=cert_dict[infoString]['subject'].get('CN',' ')+cert_dict[infoString].get('subjectAltName','')
                    df['subject_match'] = [alpha.find(cert_dict['indicator']) != -1]
                    df['alt_subjects'] = [alpha.count(',')]
                    
                df['issuer']=cert_dict[infoString].get('issuer',{}).get('CN')
                issuers[df['issuer'][0] or '']+=1
                df['keyUsage']=[cert_dict[infoString].get('keyUsage','').split(',')]
                df['extendedKeyUsage']=[cert_dict[infoString].get('extendedKeyUsage','').split(',')]
                for x in df['keyUsage'][0]:
                    usage_types[x]+=1
                
                for q in cert_dict[infoString]:
                    if (q in col_check):
                        df[q]=[cert_dict[infoString][q]]
                        
            lamow.append(df)
    except Exception as e:
        print(e)
        continue

# %%
df=pd.concat(lamow,axis=0)

def convertToDt(date_string):
    try:
        if (type(date_string) != float):
            return datetime.datetime.strptime(date_string,'%Y/%m/%d %H:%M.%S')
        else:
            return None
    except Exception as e:
        print(date_string)
        print(e)
        
df['notAfter']=df['notAfter'].apply(convertToDt)
df['notBefore']=df['notBefore'].apply(convertToDt)
df
# Out:
# /home/ubuntu/anaconda3/envs/amazonei_tensorflow_p36/lib/python3.6/site-packages/ipykernel/__main__.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   if __name__ == '__main__':
#     alt_subjects                                authorityInfoAccess  \
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# ..           ...                                                ...
# 0            NaN                                                NaN
# 0            1.0  CA Issuers - URI:http://crt.comodoca.com/COMOD...
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            1.0  CA Issuers - URI:http://crt.comodoca.com/COMOD...
# 0            NaN                                                NaN
# 0            1.0  CA Issuers - URI:http://crt.comodoca.com/COMOD...
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            1.0  CA Issuers - URI:http://crt.comodoca.com/COMOD...
# 0            NaN                                                NaN
# 0            1.0  CA Issuers - URI:http://crt.comodoca.com/COMOD...
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            1.0  CA Issuers - URI:http://crt.comodoca.com/COMOD...
# 0            NaN                                                NaN
# 0            1.0  CA Issuers - URI:http://crt.comodoca.com/COMOD...
# 0            NaN                                                NaN
# 0            1.0  CA Issuers - URI:http://crt.comodoca.com/COMOD...
# 0            NaN                                                NaN
# 0            1.0  CA Issuers - URI:http://crt.comodoca.com/COMOD...
# 0            NaN                                                NaN
# 0            1.0  CA Issuers - URI:http://crt.comodoca.com/COMOD...
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            1.0  CA Issuers - URI:http://crt.comodoca.com/COMOD...
# 0            NaN                                                NaN
# 0            NaN                                                NaN
# 0            1.0  CA Issuers - URI:http://crt.comodoca.com/COMOD...
# 0            NaN                                                NaN
#
#    basicConstraints  benign cert_validation  \
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# ..              ...     ...             ...
# 0               NaN   False             NaN
# 0          CA:FALSE   False            None
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0          CA:FALSE   False            None
# 0               NaN   False             NaN
# 0          CA:FALSE   False            None
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0          CA:FALSE   False            None
# 0               NaN   False             NaN
# 0          CA:FALSE   False            None
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0          CA:FALSE   False            None
# 0               NaN   False             NaN
# 0          CA:FALSE   False            None
# 0               NaN   False             NaN
# 0          CA:FALSE   False            None
# 0               NaN   False             NaN
# 0          CA:FALSE   False            None
# 0               NaN   False             NaN
# 0          CA:FALSE   False            None
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0          CA:FALSE   False            None
# 0               NaN   False             NaN
# 0               NaN   False             NaN
# 0          CA:FALSE   False            None
# 0               NaN   False             NaN
#
#                                   certificatePolicies  \
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# 0                                                 NaN
# ..                                                ...
# 0                                                 NaN
# 0   Policy: 1.3.6.1.4.1.6449.1.2.2.7\n  CPS: https...
# 0                                                 NaN
# 0                                                 NaN
# 0   Policy: 1.3.6.1.4.1.6449.1.2.2.7\n  CPS: https...
# 0                                                 NaN
# 0   Policy: 1.3.6.1.4.1.6449.1.2.2.7\n  CPS: https...
# 0                                                 NaN
# 0                                                 NaN
# 0   Policy: 1.3.6.1.4.1.6449.1.2.2.7\n  CPS: https...
# 0                                                 NaN
# 0   Policy: 1.3.6.1.4.1.6449.1.2.2.7\n  CPS: https...
# 0                                                 NaN
# 0                                                 NaN
# 0   Policy: 1.3.6.1.4.1.6449.1.2.2.7\n  CPS: https...
# 0                                                 NaN
# 0   Policy: 1.3.6.1.4.1.6449.1.2.2.7\n  CPS: https...
# 0                                                 NaN
# 0   Policy: 1.3.6.1.4.1.6449.1.2.2.7\n  CPS: https...
# 0                                                 NaN
# 0   Policy: 1.3.6.1.4.1.6449.1.2.2.7\n  CPS: https...
# 0                                                 NaN
# 0   Policy: 1.3.6.1.4.1.6449.1.2.2.7\n  CPS: https...
# 0                                                 NaN
# 0                                                 NaN
# 0   Policy: 1.3.6.1.4.1.6449.1.2.2.7\n  CPS: https...
# 0                                                 NaN
# 0                                                 NaN
# 0   Policy: 1.3.6.1.4.1.6449.1.2.2.7\n  CPS: https...
# 0                                                 NaN
#
#                                            error_type  \
# 0                                          [Errno -4]
# 0                                          [Errno -4]
# 0                                          [Errno -4]
# 0                                          [Errno -4]
# 0                                          [Errno -4]
# 0                                          [Errno -4]
# 0                                          [Errno -4]
# 0                                          [Errno -4]
# 0                                          [Errno -4]
# 0                                         [Errno 111]
# 0                                          [Errno -4]
# 0   EOF occurred in violation of protocol (_ssl.c:...
# 0                                          [Errno -4]
# 0                                          [Errno -4]
# 0   EOF occurred in violation of protocol (_ssl.c:...
# 0   EOF occurred in violation of protocol (_ssl.c:...
# 0   EOF occurred in violation of protocol (_ssl.c:...
# 0                    [SSL: CERTIFICATE_VERIFY_FAILED]
# 0   EOF occurred in violation of protocol (_ssl.c:...
# 0                                          [Errno -4]
# 0                                          [Errno -4]
# 0   EOF occurred in violation of protocol (_ssl.c:...
# 0   EOF occurred in violation of protocol (_ssl.c:...
# 0   EOF occurred in violation of protocol (_ssl.c:...
# 0                                          [Errno -4]
# 0                                          [Errno -4]
# 0                                          [Errno -4]
# 0   EOF occurred in violation of protocol (_ssl.c:...
# 0   EOF occurred in violation of protocol (_ssl.c:...
# 0                                          [Errno -4]
# ..                                                ...
# 0                                         [Errno 111]
# 0                                                 NaN
# 0                                         [Errno 111]
# 0                                         [Errno 111]
# 0                                                 NaN
# 0                                         [Errno 111]
# 0                                                 NaN
# 0                                         [Errno 111]
# 0                                         [Errno 111]
# 0                                                 NaN
# 0                                         [Errno 111]
# 0                                                 NaN
# 0                                         [Errno 111]
# 0                                         [Errno 111]
# 0                                                 NaN
# 0                                         [Errno 111]
# 0                                                 NaN
# 0                                         [Errno 111]
# 0                                                 NaN
# 0                                         [Errno 111]
# 0                                                 NaN
# 0                                         [Errno 111]
# 0                                                 NaN
# 0                                         [Errno 111]
# 0                                         [Errno 111]
# 0                                                 NaN
# 0                                         [Errno 111]
# 0                                         [Errno 111]
# 0                                                 NaN
# 0                                         [Errno 111]
#
#                                      extendedKeyUsage has_expired  \
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# ..                                                ...         ...
# 0                                                 NaN         NaN
# 0   [TLS Web Server Authentication,  TLS Web Clien...       False
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0   [TLS Web Server Authentication,  TLS Web Clien...       False
# 0                                                 NaN         NaN
# 0   [TLS Web Server Authentication,  TLS Web Clien...       False
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0   [TLS Web Server Authentication,  TLS Web Clien...       False
# 0                                                 NaN         NaN
# 0   [TLS Web Server Authentication,  TLS Web Clien...       False
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0   [TLS Web Server Authentication,  TLS Web Clien...       False
# 0                                                 NaN         NaN
# 0   [TLS Web Server Authentication,  TLS Web Clien...       False
# 0                                                 NaN         NaN
# 0   [TLS Web Server Authentication,  TLS Web Clien...       False
# 0                                                 NaN         NaN
# 0   [TLS Web Server Authentication,  TLS Web Clien...       False
# 0                                                 NaN         NaN
# 0   [TLS Web Server Authentication,  TLS Web Clien...       False
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0   [TLS Web Server Authentication,  TLS Web Clien...       False
# 0                                                 NaN         NaN
# 0                                                 NaN         NaN
# 0   [TLS Web Server Authentication,  TLS Web Clien...       False
# 0                                                 NaN         NaN
#
#                                  indicator  \
# 0                contactlistsagregator.com
# 0                           interrafcu.com
# 0                            onlinemail.kz
# 0                      tonsandmillions.com
# 0                      usstaffing.services
# 0           http://204.155.30.109/3521.txt
# 0                      api.cloudservers.kz
# 0                       mail.rediffmail.kz
# 0                     secure.cloudserv.ink
# 0                           204.155.30.109
# 0                                aarhje.ws
# 0                             aogafrnyf.cn
# 0                                 avxtr.ws
# 0                           calyjazzwpw.ws
# 0                              cpnecerv.cn
# 0                              czldizeq.cn
# 0                                dbgygc.cn
# 0                              flwoly.info
# 0                              fpeuphvd.cn
# 0                              ghpzsijj.ws
# 0                              giufqrjl.ws
# 0                              gsnlyvze.cn
# 0                              gtwnxros.cn
# 0                            hygbsumjpp.cn
# 0                             ikjmopows.ws
# 0                                imlslh.ws
# 0                             itqiljgku.ws
# 0                           iveopzqwfkt.cn
# 0                                 jccsv.cn
# 0                           jcvpwunredy.ws
# ..                                     ...
# 0   94d372b00f1cc0a2c15c3e9f6c24767a.cz.cc
# 0   9b1b95dd90dcc81d230ae46eb6c5689c.co.cc
# 0   9b1b95dd90dcc81d230ae46eb6c5689c.cz.cc
# 0   aab8d1f1bdaa847344c990ed7678e897.cz.cc
# 0   ac05c6c8107c79f750e85a674061ff2e.co.cc
# 0   ac05c6c8107c79f750e85a674061ff2e.cz.cc
# 0   ad169be8325a26349657b157afa67b3d.co.cc
# 0   ad169be8325a26349657b157afa67b3d.cz.cc
# 0   ad51ce5e22e976fb13bf433fff6eed05.cz.cc
# 0   ae82c3c83a1ecb4e5e1f8f95eaaafb00.co.cc
# 0   ae82c3c83a1ecb4e5e1f8f95eaaafb00.cz.cc
# 0   b5858a304cdd1605ac00550e4ed53c02.co.cc
# 0   b5858a304cdd1605ac00550e4ed53c02.cz.cc
# 0   bc90c81cab9bb2fb97d7d870362a4f3d.cz.cc
# 0   bd44efa2986c5c80a7718ef26ee3e4e3.co.cc
# 0   bd44efa2986c5c80a7718ef26ee3e4e3.cz.cc
# 0   c6dcdc2ca71595921ccce28ba3801c5c.co.cc
# 0   c6dcdc2ca71595921ccce28ba3801c5c.cz.cc
# 0   d04c0c1dbc1bf7d684adc85e5b56cb76.co.cc
# 0   d04c0c1dbc1bf7d684adc85e5b56cb76.cz.cc
# 0   d0f16da7fb2ea273916946e7f5a0fa6e.co.cc
# 0   d0f16da7fb2ea273916946e7f5a0fa6e.cz.cc
# 0   e6b3beb1d5e1b535a3c194b14b4121dd.co.cc
# 0   e6b3beb1d5e1b535a3c194b14b4121dd.cz.cc
# 0   ea19b615c029740607677c43ea888321.cz.cc
# 0   f59ee8ebeee66d5f42b9eb0ea8864d66.co.cc
# 0   f59ee8ebeee66d5f42b9eb0ea8864d66.cz.cc
# 0   f7563131fa3e2262b6e1b682bdd0fbbb.cz.cc
# 0   fe535296b31c48576787f067a8b4f8b7.co.cc
# 0   fe535296b31c48576787f067a8b4f8b7.cz.cc
#
#                                            issuer  \
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# 0                                             NaN
# ..                                            ...
# 0                                             NaN
# 0   COMODO RSA Domain Validation Secure Server CA
# 0                                             NaN
# 0                                             NaN
# 0   COMODO RSA Domain Validation Secure Server CA
# 0                                             NaN
# 0   COMODO RSA Domain Validation Secure Server CA
# 0                                             NaN
# 0                                             NaN
# 0   COMODO RSA Domain Validation Secure Server CA
# 0                                             NaN
# 0   COMODO RSA Domain Validation Secure Server CA
# 0                                             NaN
# 0                                             NaN
# 0   COMODO RSA Domain Validation Secure Server CA
# 0                                             NaN
# 0   COMODO RSA Domain Validation Secure Server CA
# 0                                             NaN
# 0   COMODO RSA Domain Validation Secure Server CA
# 0                                             NaN
# 0   COMODO RSA Domain Validation Secure Server CA
# 0                                             NaN
# 0   COMODO RSA Domain Validation Secure Server CA
# 0                                             NaN
# 0                                             NaN
# 0   COMODO RSA Domain Validation Secure Server CA
# 0                                             NaN
# 0                                             NaN
# 0   COMODO RSA Domain Validation Secure Server CA
# 0                                             NaN
#
#                                   keyUsage             notAfter  \
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# ..                                     ...                  ...
# 0                                      NaN                  NaN
# 0   [Digital Signature,  Key Encipherment]  2019/12/24 23:59.59
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0   [Digital Signature,  Key Encipherment]  2019/12/24 23:59.59
# 0                                      NaN                  NaN
# 0   [Digital Signature,  Key Encipherment]  2019/12/24 23:59.59
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0   [Digital Signature,  Key Encipherment]  2019/12/24 23:59.59
# 0                                      NaN                  NaN
# 0   [Digital Signature,  Key Encipherment]  2019/12/24 23:59.59
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0   [Digital Signature,  Key Encipherment]  2019/12/24 23:59.59
# 0                                      NaN                  NaN
# 0   [Digital Signature,  Key Encipherment]  2019/12/24 23:59.59
# 0                                      NaN                  NaN
# 0   [Digital Signature,  Key Encipherment]  2019/12/24 23:59.59
# 0                                      NaN                  NaN
# 0   [Digital Signature,  Key Encipherment]  2019/12/24 23:59.59
# 0                                      NaN                  NaN
# 0   [Digital Signature,  Key Encipherment]  2019/12/24 23:59.59
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0   [Digital Signature,  Key Encipherment]  2019/12/24 23:59.59
# 0                                      NaN                  NaN
# 0                                      NaN                  NaN
# 0   [Digital Signature,  Key Encipherment]  2019/12/24 23:59.59
# 0                                      NaN                  NaN
#
#               notBefore subject_match  success
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# ..                  ...           ...      ...
# 0                   NaN           NaN    False
# 0   2018/12/24 00:00.00         False     True
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0   2018/12/24 00:00.00         False     True
# 0                   NaN           NaN    False
# 0   2018/12/24 00:00.00         False     True
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0   2018/12/24 00:00.00         False     True
# 0                   NaN           NaN    False
# 0   2018/12/24 00:00.00         False     True
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0   2018/12/24 00:00.00         False     True
# 0                   NaN           NaN    False
# 0   2018/12/24 00:00.00         False     True
# 0                   NaN           NaN    False
# 0   2018/12/24 00:00.00         False     True
# 0                   NaN           NaN    False
# 0   2018/12/24 00:00.00         False     True
# 0                   NaN           NaN    False
# 0   2018/12/24 00:00.00         False     True
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0   2018/12/24 00:00.00         False     True
# 0                   NaN           NaN    False
# 0                   NaN           NaN    False
# 0   2018/12/24 00:00.00         False     True
# 0                   NaN           NaN    False
#
# [1891 rows x 16 columns]

# %%
# Out:
# ['Digital Signature', ' Key Encipherment']

# %%
general_types=set()
for x in error_types:
    if x.find('[SSL: CERTIFICATE_VERIFY_FAILED]') != -1:
        general_types.add(re.findall(":[ \w]*,", x)[0][2:-1])

# %%
authorityInfoAccess	sd=df[df.benign ==True]

# %%
sd[sd.success == False]['success'].value

# %%
with open('cert_info.pickle', 'wb') as output:  # Overwrites any existing file.
    pickle.dump(df, output, pickle.HIGHEST_PROTOCOL)
    
with open('error_types.pickle', 'wb') as output:  # Overwrites any existing file.
    pickle.dump(error_types, output, pickle.HIGHEST_PROTOCOL)
    
with open('validation_types.pickle', 'wb') as output:  # Overwrites any existing file.
    pickle.dump(validation_types, output, pickle.HIGHEST_PROTOCOL)
    
with open('usage_types.pickle', 'wb') as output:  # Overwrites any existing file.
    pickle.dump(usage_types, output, pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# ## Duration of valididty as feature

# %%
cert_info=json.load(open('/data/data/newNONTORbenigndata/enrichment/cert_info/999.json'))
cert_info=cert_info['data']
